# %%
import scipy.io
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

import sys
sys.path.insert(0,'../scripts/')
from processOCV import processOCV

# %% [markdown]
# #### Import Model

# %%
model = processOCV('../data/P14_OCV/')
model.run()

# %% [markdown]
# #### Plot SOC vs OCV for all temperatures

# %%
plt.figure(figsize=(10,7))
for temp in model.temps:
    plt.plot(model.SOC,model.model[temp]['rawocv'],label=temp)
plt.legend()
plt.ylabel('Voltage (V)',fontsize=16)
plt.xlabel('State of Charge',fontsize=16)
# Out:
# Text(0.5, 0, 'State of Charge')

# %%
# Input Temperature (T) and State of Charge (z)
T = 25
z = 0.5
OCV, OCV_T = model.SOC_temp_to_OCV(z,T)
# Out:
# Estimated Open Circuit Voltage (T=25 C,SOC=0.500000): 3.860000

# %%
plt.figure(figsize=(10,7))
plt.plot(model.SOC,OCV_T,label=T)
plt.legend()
plt.ylabel('Voltage (V)',fontsize=16)
plt.xlabel('State of Charge',fontsize=16)
# Out:
# Text(0.5, 0, 'State of Charge')
